# %% [markdown]
# ![banner.png](attachment:banner.png)

# %% [markdown]
# # Deep learning - Semana 4: Regularización y calibración en Deep Learning
# ## Redes neuronales: Métodos de regularización con Keras
#
# ### Propósito
# En esta actividad podrán poner en práctica el uso de diferentes métodos de regularización para la calibración de hiper-parámetros en una red neuronal de tipo feedforward. En particular, usaremos métodos de penalización de norma 1 y norma 2, "dropout" e "earlystopping" implementados en el paquete Keras.
#
# ### Instrucciones generales
#
# 1. Para realizar la actividad solo siga las indicaciones asociadas a cada celda del notebook. Sin embargo, siéntase libre de modificar el archivo editando las celdas, lo que le permitirá afianzar su comprensión sobre las distintas funcionalidades de código.
#
# 2. Recuerde que para esta actividad NO necesita realizar ningún tipo de entrega.
#
# ### Librerías a importar
#
# A continuación se muestran los comandos a ejecutar para poder implementar los procedimientos de este notebook:

# %%
from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense
import pandas as pd
from sklearn.model_selection import train_test_split
from keras import regularizers
from keras.layers.core import Dropout
from keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt

# %% [markdown]
# ### Cargando los datos
#
# En primer lugar, cargaremos datos del National Institute of Diabetes and Digestive and Kidney Diseases.
#
# En este contexto, la variable de respuesta corresponde a si la observación corresponde a un paciente con diabetes (y=1) o si no lo es (y=0) y las variables predictivas son las siguientes:
#
#
# 1. Número de veces en embarazo
# 2. Concentración de glucosa a 2 horas de test de tolerancia
# 3. Presión sanguínea diastólica
# 4. Grosor de pliegue de triceps
# 5. Insulina 2 horas
# 6. Índice de masa corporal
# 7. Función de pedigree de diabetes
# 8. Edad

# %%
# Cargar los datos
dataset = pd.read_csv('test2.csv', sep=",").to_numpy()  
X_train, X_test, y_train, y_test = train_test_split(dataset[:,0:8], dataset[:,8], test_size=0.20)

# %%
data = pd.read_csv('BankChurners.csv', sep=",")
data = data.iloc[:, :-2]

# Crear variables dummy para las columnas especificadas
data['Attrited_Indicator'] = (data['Attrition_Flag'] == 'Attrited Customer').astype(int)
data = data.select_dtypes(exclude=['object'])
data = data.dropna()
dataset = data.drop(columns=['CLIENTNUM'])
dataset= dataset.to_numpy()  
X_train, X_test, y_train, y_test = train_test_split(dataset[:,0:-1], dataset[:,-1], test_size=0.20)

# %% [markdown]
# ### Definición del modelo sin regularización
# Se define el modelo con 3 capas. Cada una con una función de activación y un número de neuronas, así:

# %%
model = Sequential()
model.add(Dense(30, input_dim=14, activation='relu'))
model.add(Dense(20, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# ### Penalización
#
# En general, el problema que se aborda en machine learning corresponde a encontrar la función que minimice cierta función de pérdida:
#
# $$\hat{\theta}=argmin_{\theta\in\mathcal{R^{p}}}\mathcal{J}(\theta,X,y)$$
#
# De esta manera, en un problema de regresión, $\mathcal{J}(\theta,X,y)$ corresponde al error cuadrático medio y, en un problema de clasificación con dos clases, corresponde a la función de entropía cruzada binaria.
#
# Sin embargo, para evitar el problema de sobreajuste, es posible añadir un término de penalización adicional a la función de pérdida y así sea posible regularizar la función que se obtiene en este proceso. De manera analítica se tendría lo siguiente:
#
# $$\hat{\theta}=argmin_{\theta\in\mathcal{R^{p}}}\mathcal{J}(\theta,X,y)+\alpha\Omega(\theta)$$
#
# Donde $\alpha\Omega(\theta)$ es un término que típicamente restringe la complejidad o flexibilidad de la función a estimar. Por ejemplo, en un modelo de regresión lineal, es posible utilizar un término de penalización que restrinja el tamaño del vector de parámetros:
#
# $$\hat{\beta}=argmin_{\beta \in\mathcal{R}^{p}}(Y-X\beta)^{T}(Y-X\beta)+\alpha||\beta||^{m}$$
#
# Donde $||v||^{m}$ correponde a la norma $L^{m}$ del vector $v$ en el espacio correspondiente.
#
#
# ### Penalización $L^{1}$
#
# En este caso, se está utilizando la siguiente expresión para la penalización de la función de pérdida:
#
# $$\hat{w}=argmin_{w\in\mathcal{R^{p}}}\mathcal{J}(w,X,y)+\alpha \sum_{i=1}^{p}|w_{i}|$$
#
# Donde $|a|$ corresponde al valor absoluto del número $a$.
#
# Así, para implementar este tipo de penalización en cada una de las capas, utilizamos el siguiente código, donde se utilizan 3 capas en la definición del modelo y se establece $\alpha=0.01$:

# %%
model1 = Sequential()
model1.add(Dense(30, input_dim=14, activation='relu', kernel_regularizer=regularizers.l1(0.01)))
model1.add(Dense(20, activation='relu',  kernel_regularizer=regularizers.l1(0.01)))
model1.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# ### Penalización $L^{2}$
# En este caso, se está utilizando la siguiente expresión para la penalización de la función de pérdida:
#
# $$\hat{w}=argmin_{\theta\in\mathcal{R^{p}}}\mathcal{J}(w,X,y)+\alpha \sum_{i=1}^{p}w_{i}^{2}$$
#
# Así, para implementar este tipo de penalización en cada una de las capas, utilizamos el siguiente código, donde se utilizan 3 capas en la definición del modelo y se establece $\alpha=0.01$:

# %%
model2 = Sequential()
model2.add(Dense(30, input_dim=14, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
model2.add(Dense(20, activation='relu',  kernel_regularizer=regularizers.l2(0.001)))
model2.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# ### Dropout
#
# Este tipo de regularización corresponde a imponer la restricción de que algunos pesos sean iguales a cero con cierta probabilidad determinada por parámetro. Es decir, se tiene la siguiente definición para los parámetros de los pesos:
#
# $$\hat{w}_{i}=(1-B_{i})w_{i}$$
#
# Donde:
#
# $$B_{i} \sim Bernoulli(p_{i})$$
#
# y $p_i$ es la probabilidad de abandono o _dropout_. Para implementar lo anterior se utiliza el siguiente código para un modelo con tres capas y $p_{i}=0.05$ para todos los nodos:

# %%
modeldp = Sequential()
modeldp.add(Dense(30, input_dim=14, activation='relu'))
modeldp.add(Dropout(0.05))
modeldp.add(Dense(20, activation='relu'))
modeldp.add(Dropout(0.05))
modeldp.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# ### Early stopping
# Este tipo de regularización hace que el procedimiento de optimización de gradiente descendiente no se realice hasta su convergencia, sino que se detenga de manera temprana para así evitar el sobreajuste de los datos, evitando una función de pérdida muy baja que podría ser engañosa. Para implementar esto, construiremos una red neuronal y se utilizará el callback EarlyStopping cuando se ajuste el modelo (instrucción ".fit").

# %%
modeles = Sequential()
modeles.add(Dense(30, input_dim=14, activation='relu'))
modeles.add(Dense(20, activation='relu'))
modeles.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# ### Compilación de los modelos
#
# Se debe seleccionar un función de pérdida, que en este caso es la función cross-entropy, el optimizador y el accuracy que se quiere evaluar.

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model1.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model2.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
modeldp.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
modeles.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# Se entrenan los modelos con los datos de entrenamiento

# %%
history=model.fit(X_train, y_train, epochs=25, batch_size=10 )
history1=model1.fit(X_train, y_train, epochs=25, batch_size=10 )
history2=model2.fit(X_train, y_train, epochs=25, batch_size=10 )
historydp=modeldp.fit(X_train, y_train, epochs=25, batch_size=10 )
historyes=modeles.fit(X_train, y_train, epochs=25, batch_size=10 , callbacks = [EarlyStopping(monitor='val_acc', patience=2)])
# Out:
# Epoch 1/25
# 811/811 [==============================] - 3s 2ms/step - loss: 24.9577 - accuracy: 0.7787
# Epoch 2/25
# 811/811 [==============================] - 2s 2ms/step - loss: 9.4550 - accuracy: 0.7861
# Epoch 3/25
# 811/811 [==============================] - 2s 2ms/step - loss: 12.3824 - accuracy: 0.7874
# Epoch 4/25
# 811/811 [==============================] - 2s 2ms/step - loss: 8.3160 - accuracy: 0.7956
# Epoch 5/25
# 811/811 [==============================] - 2s 2ms/step - loss: 7.9393 - accuracy: 0.7932
# Epoch 6/25
# 811/811 [==============================] - 2s 2ms/step - loss: 5.9287 - accuracy: 0.8055
# Epoch 7/25
# 811/811 [==============================] - 2s 2ms/step - loss: 4.8367 - accuracy: 0.8034
# Epoch 8/25
# 811/811 [==============================] - 2s 2ms/step - loss: 6.1484 - accuracy: 0.7998
# Epoch 9/25
# 811/811 [==============================] - 2s 2ms/step - loss: 4.6231 - accuracy: 0.8078
# Epoch 10/25
# 811/811 [==============================] - 2s 2ms/step - loss: 3.9370 - accuracy: 0.8108
# Epoch 11/25
# 811/811 [==============================] - 2s 2ms/step - loss: 4.2110 - accuracy: 0.8121
# Epoch 12/25
# 811/811 [==============================] - 2s 2ms/step - loss: 3.9132 - accuracy: 0.8094
# Epoch 13/25
# 811/811 [==============================] - 2s 2ms/step - loss: 3.3223 - accuracy: 0.8205
# Epoch 14/25
# 811/811 [==============================] - 2s 2ms/step - loss: 2.6480 - accuracy: 0.8242
# Epoch 15/25
# 811/811 [==============================] - 2s 2ms/step - loss: 2.8330 - accuracy: 0.8164
# Epoch 16/25
# 811/811 [==============================] - 2s 3ms/step - loss: 2.6449 - accuracy: 0.8235
# Epoch 17/25
# 811/811 [==============================] - 2s 3ms/step - loss: 2.3629 - accuracy: 0.8177
# Epoch 18/25
# 811/811 [==============================] - 2s 2ms/step - loss: 1.9723 - accuracy: 0.8285
# Epoch 19/25
# 811/811 [==============================] - 2s 2ms/step - loss: 1.9091 - accuracy: 0.8364
# Epoch 20/25
# 811/811 [==============================] - 2s 2ms/step - loss: 1.9130 - accuracy: 0.8276
# Epoch 21/25
# 811/811 [==============================] - 2s 2ms/step - loss: 1.5138 - accuracy: 0.8393
# Epoch 22/25
# 811/811 [==============================] - 2s 2ms/step - loss: 1.9328 - accuracy: 0.8326
# Epoch 23/25
# 811/811 [==============================] - 2s 2ms/step - loss: 1.6369 - accuracy: 0.8317
# Epoch 24/25
# 811/811 [==============================] - 2s 2ms/step - loss: 1.4952 - accuracy: 0.8338
# Epoch 25/25
# 811/811 [==============================] - 2s 2ms/step - loss: 0.9169 - accuracy: 0.8471
# Epoch 1/25
# 811/811 [==============================] - 3s 2ms/step - loss: 37.5717 - accuracy: 0.7788
# Epoch 2/25
# 811/811 [==============================] - 2s 2ms/step - loss: 14.2512 - accuracy: 0.7818
# Epoch 3/25
# 811/811 [==============================] - 2s 2ms/step - loss: 14.2638 - accuracy: 0.7993
# Epoch 4/25
# 811/811 [==============================] - 2s 2ms/step - loss: 10.5520 - accuracy: 0.7942
# Epoch 5/25
# 811/811 [==============================] - 2s 2ms/step - loss: 10.0862 - accuracy: 0.7969
# Epoch 6/25
# 811/811 [==============================] - 2s 2ms/step - loss: 7.7983 - accuracy: 0.8019
# Epoch 7/25
# 811/811 [==============================] - 2s 2ms/step - loss: 7.1358 - accuracy: 0.8035
# Epoch 8/25
# 811/811 [==============================] - 2s 2ms/step - loss: 6.0809 - accuracy: 0.8100
# Epoch 9/25
# 811/811 [==============================] - 2s 2ms/step - loss: 6.0932 - accuracy: 0.8059
# Epoch 10/25
# 811/811 [==============================] - 2s 2ms/step - loss: 5.1610 - accuracy: 0.8142
# Epoch 11/25
# 811/811 [==============================] - 2s 2ms/step - loss: 5.0188 - accuracy: 0.8126
# Epoch 12/25
# 811/811 [==============================] - 2s 2ms/step - loss: 5.0821 - accuracy: 0.8185
# Epoch 13/25
# 811/811 [==============================] - 2s 2ms/step - loss: 5.3642 - accuracy: 0.8111
# Epoch 14/25
# 811/811 [==============================] - 2s 2ms/step - loss: 4.1790 - accuracy: 0.8155
# Epoch 15/25
# 811/811 [==============================] - 2s 2ms/step - loss: 3.4486 - accuracy: 0.8161
# Epoch 16/25
# 811/811 [==============================] - 2s 2ms/step - loss: 3.4084 - accuracy: 0.8179
# Epoch 17/25
# 811/811 [==============================] - 2s 2ms/step - loss: 2.8189 - accuracy: 0.8171
# Epoch 18/25
# 811/811 [==============================] - 2s 2ms/step - loss: 3.0665 - accuracy: 0.8095
# Epoch 19/25
# 811/811 [==============================] - 2s 2ms/step - loss: 2.3669 - accuracy: 0.8188
# Epoch 20/25
# 811/811 [==============================] - 2s 2ms/step - loss: 2.1730 - accuracy: 0.8194
# Epoch 21/25
# 811/811 [==============================] - 2s 2ms/step - loss: 2.2929 - accuracy: 0.8104
# Epoch 22/25
# 811/811 [==============================] - 2s 2ms/step - loss: 2.0117 - accuracy: 0.8151
# Epoch 23/25
# 811/811 [==============================] - 2s 2ms/step - loss: 1.6218 - accuracy: 0.8162
# Epoch 24/25
# 811/811 [==============================] - 2s 2ms/step - loss: 1.5197 - accuracy: 0.8194
# Epoch 25/25
# 811/811 [==============================] - 2s 2ms/step - loss: 1.3048 - accuracy: 0.8226
# Epoch 1/25
# 811/811 [==============================] - 2s 2ms/step - loss: 30.5446 - accuracy: 0.7795
# Epoch 2/25
# 811/811 [==============================] - 2s 2ms/step - loss: 10.3939 - accuracy: 0.7842
# Epoch 3/25
# 811/811 [==============================] - 2s 2ms/step - loss: 6.8869 - accuracy: 0.7890
# Epoch 4/25
# 811/811 [==============================] - 2s 2ms/step - loss: 8.4214 - accuracy: 0.7877
# Epoch 5/25
# 811/811 [==============================] - 2s 2ms/step - loss: 6.0970 - accuracy: 0.7974
# Epoch 6/25
# 811/811 [==============================] - 2s 2ms/step - loss: 7.6007 - accuracy: 0.7958
# Epoch 7/25
# 811/811 [==============================] - 2s 2ms/step - loss: 5.1013 - accuracy: 0.8021
# Epoch 8/25
# 811/811 [==============================] - 2s 2ms/step - loss: 5.2995 - accuracy: 0.8015
# Epoch 9/25
# 811/811 [==============================] - 2s 2ms/step - loss: 3.6276 - accuracy: 0.8045
# Epoch 10/25
# 811/811 [==============================] - 2s 2ms/step - loss: 4.3378 - accuracy: 0.8053
# Epoch 11/25
# 811/811 [==============================] - 2s 2ms/step - loss: 4.2012 - accuracy: 0.8061
# Epoch 12/25
# 811/811 [==============================] - 2s 2ms/step - loss: 3.3393 - accuracy: 0.8141
# Epoch 13/25
# 811/811 [==============================] - 2s 2ms/step - loss: 3.4540 - accuracy: 0.8142
# Epoch 14/25
# 811/811 [==============================] - 2s 2ms/step - loss: 3.4765 - accuracy: 0.8118
# Epoch 15/25
# 811/811 [==============================] - 2s 2ms/step - loss: 2.5137 - accuracy: 0.8208
# Epoch 16/25
# 811/811 [==============================] - 2s 2ms/step - loss: 2.4811 - accuracy: 0.8193
# Epoch 17/25
# 811/811 [==============================] - 2s 2ms/step - loss: 1.6647 - accuracy: 0.8288
# Epoch 18/25
# 811/811 [==============================] - 2s 2ms/step - loss: 2.1307 - accuracy: 0.8227
# Epoch 19/25
# 811/811 [==============================] - 2s 2ms/step - loss: 1.5903 - accuracy: 0.8162
# Epoch 20/25
# 811/811 [==============================] - 2s 2ms/step - loss: 1.7992 - accuracy: 0.8155
# Epoch 21/25
# 811/811 [==============================] - 2s 3ms/step - loss: 1.7371 - accuracy: 0.8257
# Epoch 22/25
# 811/811 [==============================] - 2s 3ms/step - loss: 1.3378 - accuracy: 0.8218
# Epoch 23/25
# 811/811 [==============================] - 2s 2ms/step - loss: 1.0381 - accuracy: 0.8252
# Epoch 24/25
# 811/811 [==============================] - 2s 2ms/step - loss: 0.7290 - accuracy: 0.8378
# Epoch 25/25
# 811/811 [==============================] - 2s 3ms/step - loss: 0.6537 - accuracy: 0.8367
# Epoch 1/25
# 811/811 [==============================] - 2s 2ms/step - loss: 46.7494 - accuracy: 0.7619
# Epoch 2/25
# 811/811 [==============================] - 2s 2ms/step - loss: 4.6878 - accuracy: 0.7418
# Epoch 3/25
# 811/811 [==============================] - 2s 2ms/step - loss: 0.9252 - accuracy: 0.8343
# Epoch 4/25
# 811/811 [==============================] - 2s 2ms/step - loss: 0.5412 - accuracy: 0.8364
# Epoch 5/25
# 811/811 [==============================] - 2s 2ms/step - loss: 0.5808 - accuracy: 0.8374
# Epoch 6/25
# 811/811 [==============================] - 2s 2ms/step - loss: 0.4922 - accuracy: 0.8369
# Epoch 7/25
# 811/811 [==============================] - 2s 2ms/step - loss: 0.4677 - accuracy: 0.8374
# Epoch 8/25
# 811/811 [==============================] - 2s 2ms/step - loss: 0.4377 - accuracy: 0.8378
# Epoch 9/25
# 811/811 [==============================] - 2s 2ms/step - loss: 0.4485 - accuracy: 0.8378
# Epoch 10/25
# 811/811 [==============================] - 2s 2ms/step - loss: 0.4356 - accuracy: 0.8380
# Epoch 11/25
# 811/811 [==============================] - 2s 2ms/step - loss: 0.4264 - accuracy: 0.8380
# Epoch 12/25
# 811/811 [==============================] - 2s 2ms/step - loss: 0.4424 - accuracy: 0.8377
# Epoch 13/25
# 811/811 [==============================] - 2s 2ms/step - loss: 0.4467 - accuracy: 0.8379
# Epoch 14/25
# 811/811 [==============================] - 2s 3ms/step - loss: 0.4202 - accuracy: 0.8380
# Epoch 15/25
# 811/811 [==============================] - 2s 2ms/step - loss: 0.4784 - accuracy: 0.8376
# Epoch 16/25
# 811/811 [==============================] - 2s 2ms/step - loss: 0.4335 - accuracy: 0.8379
# Epoch 17/25
# 811/811 [==============================] - 2s 2ms/step - loss: 0.4196 - accuracy: 0.8379
# Epoch 18/25
# 811/811 [==============================] - 2s 2ms/step - loss: 0.4227 - accuracy: 0.8379
# Epoch 19/25
# 811/811 [==============================] - 2s 2ms/step - loss: 0.4203 - accuracy: 0.8379
# Epoch 20/25
# 811/811 [==============================] - 2s 2ms/step - loss: 0.4208 - accuracy: 0.8379
# Epoch 21/25
# 811/811 [==============================] - 2s 2ms/step - loss: 0.4340 - accuracy: 0.8377
# Epoch 22/25
# 811/811 [==============================] - 2s 2ms/step - loss: 0.4221 - accuracy: 0.8378
# Epoch 23/25
# 811/811 [==============================] - 2s 2ms/step - loss: 0.4205 - accuracy: 0.8379
# Epoch 24/25
# 811/811 [==============================] - 2s 2ms/step - loss: 0.4216 - accuracy: 0.8379
# Epoch 25/25
# 811/811 [==============================] - 2s 2ms/step - loss: 0.4197 - accuracy: 0.8379
# Epoch 1/25
# 786/811 [============================>.] - ETA: 0s - loss: 28.0952 - accuracy: 0.7821WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy
# 811/811 [==============================] - 2s 2ms/step - loss: 27.4335 - accuracy: 0.7814
# Epoch 2/25
# 811/811 [==============================] - ETA: 0s - loss: 11.0380 - accuracy: 0.7905WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy
# 811/811 [==============================] - 2s 2ms/step - loss: 11.0380 - accuracy: 0.7905
# Epoch 3/25
# 796/811 [============================>.] - ETA: 0s - loss: 11.3575 - accuracy: 0.7920WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy
# 811/811 [==============================] - 2s 2ms/step - loss: 11.2365 - accuracy: 0.7921
# Epoch 4/25
# 811/811 [==============================] - ETA: 0s - loss: 9.0580 - accuracy: 0.7995WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy
# 811/811 [==============================] - 2s 2ms/step - loss: 9.0580 - accuracy: 0.7995
# Epoch 5/25
# 793/811 [============================>.] - ETA: 0s - loss: 9.1499 - accuracy: 0.8001WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy
# 811/811 [==============================] - 2s 2ms/step - loss: 9.0935 - accuracy: 0.8008
# Epoch 6/25
# 810/811 [============================>.] - ETA: 0s - loss: 10.0667 - accuracy: 0.8007WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy
# 811/811 [==============================] - 2s 2ms/step - loss: 10.0766 - accuracy: 0.8006
# Epoch 7/25
# 791/811 [============================>.] - ETA: 0s - loss: 6.4721 - accuracy: 0.8083WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy
# 811/811 [==============================] - 2s 2ms/step - loss: 6.3947 - accuracy: 0.8085
# Epoch 8/25
# 794/811 [============================>.] - ETA: 0s - loss: 5.7281 - accuracy: 0.8113WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy
# 811/811 [==============================] - 2s 2ms/step - loss: 5.6771 - accuracy: 0.8114
# Epoch 9/25
# 783/811 [===========================>..] - ETA: 0s - loss: 7.3294 - accuracy: 0.8055WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy
# 811/811 [==============================] - 2s 2ms/step - loss: 7.1657 - accuracy: 0.8056
# Epoch 10/25
# 796/811 [============================>.] - ETA: 0s - loss: 6.2458 - accuracy: 0.8177WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy
# 811/811 [==============================] - 2s 2ms/step - loss: 6.2805 - accuracy: 0.8162
# Epoch 11/25
# 798/811 [============================>.] - ETA: 0s - loss: 4.7364 - accuracy: 0.8263WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy
# 811/811 [==============================] - 2s 2ms/step - loss: 4.6911 - accuracy: 0.8256
# Epoch 12/25
# 806/811 [============================>.] - ETA: 0s - loss: 5.6340 - accuracy: 0.8100WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy
# 811/811 [==============================] - 1s 2ms/step - loss: 5.6370 - accuracy: 0.8101
# Epoch 13/25
# 809/811 [============================>.] - ETA: 0s - loss: 4.5003 - accuracy: 0.8146WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy
# 811/811 [==============================] - 2s 2ms/step - loss: 4.4978 - accuracy: 0.8146
# Epoch 14/25
# 793/811 [============================>.] - ETA: 0s - loss: 4.3635 - accuracy: 0.8245WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy
# 811/811 [==============================] - 2s 2ms/step - loss: 4.3344 - accuracy: 0.8251
# Epoch 15/25
# 800/811 [============================>.] - ETA: 0s - loss: 4.1314 - accuracy: 0.8205WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy
# 811/811 [==============================] - 2s 2ms/step - loss: 4.1403 - accuracy: 0.8199
# Epoch 16/25
# 803/811 [============================>.] - ETA: 0s - loss: 4.0642 - accuracy: 0.8223WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy
# 811/811 [==============================] - 2s 2ms/step - loss: 4.0608 - accuracy: 0.8219
# Epoch 17/25
# 798/811 [============================>.] - ETA: 0s - loss: 5.0445 - accuracy: 0.8122WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy
# 811/811 [==============================] - 2s 2ms/step - loss: 5.0912 - accuracy: 0.8122
# Epoch 18/25
# 795/811 [============================>.] - ETA: 0s - loss: 3.0311 - accuracy: 0.8250WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy
# 811/811 [==============================] - 2s 2ms/step - loss: 3.1769 - accuracy: 0.8221
# Epoch 19/25
# 789/811 [============================>.] - ETA: 0s - loss: 3.0499 - accuracy: 0.8215WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy
# 811/811 [==============================] - 2s 2ms/step - loss: 3.0750 - accuracy: 0.8216
# Epoch 20/25
# 779/811 [===========================>..] - ETA: 0s - loss: 3.0743 - accuracy: 0.8209WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy
# 811/811 [==============================] - 2s 2ms/step - loss: 3.0569 - accuracy: 0.8213
# Epoch 21/25
# 793/811 [============================>.] - ETA: 0s - loss: 2.4271 - accuracy: 0.8267WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy
# 811/811 [==============================] - 2s 2ms/step - loss: 2.3961 - accuracy: 0.8274
# Epoch 22/25
# 801/811 [============================>.] - ETA: 0s - loss: 2.2802 - accuracy: 0.8292WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy
# 811/811 [==============================] - 2s 2ms/step - loss: 2.2691 - accuracy: 0.8292
# Epoch 23/25
# 803/811 [============================>.] - ETA: 0s - loss: 1.9716 - accuracy: 0.8308WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy
# 811/811 [==============================] - 2s 2ms/step - loss: 1.9622 - accuracy: 0.8314
# Epoch 24/25
# 806/811 [============================>.] - ETA: 0s - loss: 1.7736 - accuracy: 0.8340WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy
# 811/811 [==============================] - 2s 2ms/step - loss: 1.7911 - accuracy: 0.8342
# Epoch 25/25
# 781/811 [===========================>..] - ETA: 0s - loss: 1.4752 - accuracy: 0.8419WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy
# 811/811 [==============================] - 2s 2ms/step - loss: 1.4802 - accuracy: 0.8409

# %% [markdown]
# Se calcula el accuracy de los modelos con las bases de datos de train

# %%
_, accuracy = model.evaluate(X_train, y_train)
print('Accuracy: %.2f' % (accuracy*100))

_, accuracy = model1.evaluate(X_train, y_train)
print('Accuracy: %.2f' % (accuracy*100))

_, accuracy = model2.evaluate(X_train, y_train)
print('Accuracy: %.2f' % (accuracy*100))

_, accuracy = modeldp.evaluate(X_train, y_train)
print('Accuracy: %.2f' % (accuracy*100))

_, accuracy = modeles.evaluate(X_train, y_train)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 254/254 [==============================] - 1s 2ms/step - loss: 0.5446 - accuracy: 0.7805
# Accuracy: 78.05
# 254/254 [==============================] - 1s 2ms/step - loss: 1.6911 - accuracy: 0.8498
# Accuracy: 84.98
# 254/254 [==============================] - 1s 2ms/step - loss: 0.5695 - accuracy: 0.8485
# Accuracy: 84.85
# 254/254 [==============================] - 1s 2ms/step - loss: 0.4142 - accuracy: 0.8379
# Accuracy: 83.79
# 254/254 [==============================] - 1s 2ms/step - loss: 1.6634 - accuracy: 0.8616
# Accuracy: 86.16

# %% [markdown]
# Se hacen predicciones utilizando los modelos

# %%
predicciones = model.predict(X_test)
redondeado = [round(x[0]) for x in predicciones]
predicciones = (model.predict(X_test) > 0.5).astype(int)

predicciones1 = model1.predict(X_test)
redondeado1 = [round(x[0]) for x in predicciones1]
predicciones1 = (model1.predict(X_test) > 0.5).astype(int)

predicciones2 = model2.predict(X_test)
redondeado2 = [round(x[0]) for x in predicciones2]
predicciones2 = (model2.predict(X_test) > 0.5).astype(int)

prediccionesdp = modeldp.predict(X_test)
redondeadodp = [round(x[0]) for x in predicciones]
prediccionesdp = (modeldp.predict(X_test) > 0.5).astype(int)


prediccioneses = modeles.predict(X_test)
redondeadoes = [round(x[0]) for x in prediccioneses]
prediccioneses = (modeles.predict(X_test) > 0.5).astype(int)
# Out:
# 64/64 [==============================] - 0s 2ms/step
# 64/64 [==============================] - 0s 2ms/step
# 64/64 [==============================] - 0s 2ms/step
# 64/64 [==============================] - 0s 2ms/step
# 64/64 [==============================] - 0s 2ms/step
# 64/64 [==============================] - 0s 2ms/step
# 64/64 [==============================] - 0s 2ms/step
# 64/64 [==============================] - 0s 2ms/step
# 64/64 [==============================] - 0s 2ms/step
# 64/64 [==============================] - 0s 2ms/step

# %% [markdown]
# Accuracy en el set de test

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
test_loss1, test_acc1 = model1.evaluate(X_test, y_test)
test_loss2, test_acc2 = model2.evaluate(X_test, y_test)
test_lossdp, test_accdp = modeldp.evaluate(X_test, y_test)
test_losses, test_acces = modeles.evaluate(X_test, y_test)
# Out:
# 64/64 [==============================] - 0s 2ms/step - loss: 0.5232 - accuracy: 0.7868
# 64/64 [==============================] - 0s 2ms/step - loss: 1.5577 - accuracy: 0.8514
# 64/64 [==============================] - 0s 2ms/step - loss: 0.5582 - accuracy: 0.8524
# 64/64 [==============================] - 0s 2ms/step - loss: 0.4021 - accuracy: 0.8450
# 64/64 [==============================] - 0s 2ms/step - loss: 1.4833 - accuracy: 0.8672

# %%
plt.figure(1)
# Graficar accuracy del modelo
plt.title('Precision del modelo')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.plot(history.history['accuracy'])
plt.plot(history1.history['accuracy'])
plt.plot(history2.history['accuracy'])
plt.plot(historydp.history['accuracy'])
plt.plot(historyes.history['accuracy'])
plt.legend(['Normal model', 'Regularization L1', 'Regularization L2', 'Dropout', 'Early stopping' ], loc='upper left')
plt.show()

# %%
# Graficar la función de pérdida evaluada
plt.title('Función de pérdida')
plt.ylabel('F hat')
plt.xlabel('Epoch')
plt.plot(history.history['loss'])
plt.plot(history1.history['loss'])
plt.plot(history2.history['loss'])
plt.plot(historydp.history['loss'])
plt.plot(historyes.history['loss'])
plt.legend(['Normal model', 'Regularization L1', 'Regularization L2', 'Dropout', 'Early stopping' ], loc='upper left')
plt.show()

# %% [markdown]
# ### Ejercicio no evaluable:
#
# Intente cambiar los hiper-parámetros para encontrar un mejor _acurracy_ en la muestra de _test_.
